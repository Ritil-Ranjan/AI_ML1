# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritil-Ranjan/AI_ML1/blob/main/Patna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yhenon/pytorch-retinanet.git
# Out:
# Cloning into 'pytorch-retinanet'...
# remote: Enumerating objects: 232, done.
# remote: Total 232 (delta 0), reused 0 (delta 0), pack-reused 232 (from 2)
# Receiving objects: 100% (232/232), 1.02 MiB | 23.20 MiB/s, done.
# Resolving deltas: 100% (116/116), done.

# %%
# !apt-get install tk-dev python-tk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tk-dev is already the newest version (8.6.11+1build2).
# The following additional packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python2 python2-minimal python2.7
#   python2.7-minimal
# Suggested packages:
#   tix python-tk-dbg python2-doc python2.7-doc binfmt-support
# The following NEW packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python-tk python2 python2-minimal
#   python2.7 python2.7-minimal
# 0 upgraded, 8 newly installed, 0 to remove and 20 not upgraded.
# Need to get 4,037 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpython2.7-minimal amd64 2.7.18-13ubuntu1.5 [347 kB]
# ...

# %%
# !pip install pandas
# !pip install pycocotools
# !pip install opencv-python
# !pip install requests

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu124

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/AI\ and\ ML/valid.zip -d /content
# Out:
# Archive:  /content/drive/MyDrive/AI and ML/valid.zip
#    creating: /content/valid/
#   inflating: /content/valid/annotations.csv
#   inflating: /content/valid/class_names.csv
#   inflating: /content/valid/trainc_588.jpg
#   inflating: /content/valid/trainc_624.jpg
#   inflating: /content/valid/trainc_628.jpg
#   inflating: /content/valid/trainc_637.jpg
#   inflating: /content/valid/trainc_641.jpg
#   inflating: /content/valid/train_107.jpg
#   inflating: /content/valid/train_111.jpg
#   inflating: /content/valid/train_125.jpg
#   inflating: /content/valid/train_130.jpg
#   inflating: /content/valid/train_142.jpg
#   inflating: /content/valid/train_151.jpg
#   inflating: /content/valid/train_162.jpg
#   inflating: /content/valid/train_171.jpg
#   inflating: /content/valid/train_173.jpg
#   inflating: /content/valid/train_180.jpg
#   inflating: /content/valid/train_195.jpg
#   inflating: /content/valid/train_203.jpg
#   inflating: /content/valid/train_210.jpg
# ...

# %%
# !pip install torch
# !pip install torch==1.11.0 torchvision==0.12.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 30.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !python pytorch-retinanet/train.py --dataset csv --csv_train train_annot.csv --csv_classes train/class_names.csv
# Out:
# CUDA available: True
# Traceback (most recent call last):
#   File "/content/pytorch-retinanet/train.py", line 180, in <module>
#     main()
#   File "/content/pytorch-retinanet/train.py", line 56, in main
#     dataset_train = CSVDataset(train_file=parser.csv_train, class_list=parser.csv_classes,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/pytorch-retinanet/retinanet/dataloader.py", line 153, in __init__
#     with self._open_for_csv(self.train_file) as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/pytorch-retinanet/retinanet/dataloader.py", line 180, in _open_for_csv
#     return open(path, 'r', newline='')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'train_annot.csv'

# %%
# !python pytorch-retinanet/train.py --dataset csv --csv_train train/train_annotations1.csv --csv_classes train/class_names.csv --csv_val valid/valid_annotations1.csv
# Out:
# CUDA available: True
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to ./resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 282MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Num training images: 1017
# Epoch: 0 | Iteration: 0 | Classification loss: 0.78261 | Regression loss: 1.00132 | Running loss: 1.78392
# ...

# %%
print("Precision array: ", precision)
print("Recall array: ", recall)
print("True positives: ", true_positives)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c9b49161b00> in <cell line: 1>()
# ----> 1 print("Precision array: ", precision)
#       2 print("Recall array: ", recall)
#       3 print("True positives: ", true_positives)
#
# NameError: name 'precision' is not defined

# %%
# !python pytorch-retinanet/coco_validation.py --coco_path ~/path/to/coco --model_path /path/to/model/coco_resnet_50_map_0_335_state_dict.pt
# Out:
# CUDA available: True
# loading annotations into memory...
# Traceback (most recent call last):
#   File "/content/pytorch-retinanet/coco_validation.py", line 49, in <module>
#     main()
#   File "/content/pytorch-retinanet/coco_validation.py", line 22, in main
#     dataset_val = CocoDataset(parser.coco_path, set_name='val2017',
#   File "/content/pytorch-retinanet/retinanet/dataloader.py", line 37, in __init__
#     self.coco      = COCO(os.path.join(self.root_dir, 'annotations', 'instances_' + self.set_name + '.json'))
#   File "/usr/local/lib/python3.10/dist-packages/pycocotools/coco.py", line 81, in __init__
#     with open(annotation_file, 'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/root/path/to/coco/annotations/instances_val2017.json'

# %%
# !pwd
# !ls -R ../coco
# Out:
# /content
# ls: cannot access '../coco': No such file or directory

# %%
# !pwd
# !ls -R ../pytorch-retinanet/coco
# Out:
# /content
# ls: cannot access '../pytorch-retinanet/coco': No such file or directory

# %%
# !pwd
# Out:
# /content

# %%
# !ls -R
# Out:
# .:
# pytorch-retinanet  sample_data
#
# ./pytorch-retinanet:
# coco_validation.py  images   README.md	train.py      visualize_single_image.py
# csv_validation.py   LICENSE  retinanet	visualize.py
#
# ./pytorch-retinanet/images:
# 1.jpg  3.jpg  4.jpg  5.jpg  6.jpg  7.jpg  8.jpg
#
# ./pytorch-retinanet/retinanet:
# anchors.py    csv_eval.py    __init__.py  model.py	  __pycache__
# coco_eval.py  dataloader.py  losses.py	  oid_dataset.py  utils.py
#
# ./pytorch-retinanet/retinanet/__pycache__:
# anchors.cpython-310.pyc    dataloader.cpython-310.pyc  model.cpython-310.pyc
# coco_eval.cpython-310.pyc  __init__.cpython-310.pyc    utils.cpython-310.pyc
# csv_eval.cpython-310.pyc   losses.cpython-310.pyc
#
# ./sample_data:
# anscombe.json		     california_housing_train.csv  mnist_train_small.csv
# california_housing_test.csv  mnist_test.csv		   README.md

# %%
# !mkdir ../coco

# %%
# !pip install pycocotools

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !python pytorch-retinanet/train.py --dataset coco --coco_path ../coco --depth 50
# Out:
# CUDA available: True
# loading annotations into memory...
# Traceback (most recent call last):
#   File "/content/pytorch-retinanet/train.py", line 180, in <module>
#     main()
#   File "/content/pytorch-retinanet/train.py", line 43, in main
#     dataset_train = CocoDataset(parser.coco_path, set_name='train2017',
#   File "/content/pytorch-retinanet/retinanet/dataloader.py", line 37, in __init__
#     self.coco      = COCO(os.path.join(self.root_dir, 'annotations', 'instances_' + self.set_name + '.json'))
#   File "/usr/local/lib/python3.10/dist-packages/pycocotools/coco.py", line 81, in __init__
#     with open(annotation_file, 'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '../coco/annotations/instances_train2017.json'
